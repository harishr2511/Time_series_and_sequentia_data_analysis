# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
np.random.seed(42)

# %%
values = np.random.randn(200)

# %%
values
# Out:
# array([ 0.49671415, -0.1382643 ,  0.64768854,  1.52302986, -0.23415337,
#        -0.23413696,  1.57921282,  0.76743473, -0.46947439,  0.54256004,
#        -0.46341769, -0.46572975,  0.24196227, -1.91328024, -1.72491783,
#        -0.56228753, -1.01283112,  0.31424733, -0.90802408, -1.4123037 ,
#         1.46564877, -0.2257763 ,  0.0675282 , -1.42474819, -0.54438272,
#         0.11092259, -1.15099358,  0.37569802, -0.60063869, -0.29169375,
#        -0.60170661,  1.85227818, -0.01349722, -1.05771093,  0.82254491,
#        -1.22084365,  0.2088636 , -1.95967012, -1.32818605,  0.19686124,
#         0.73846658,  0.17136828, -0.11564828, -0.3011037 , -1.47852199,
#        -0.71984421, -0.46063877,  1.05712223,  0.34361829, -1.76304016,
#         0.32408397, -0.38508228, -0.676922  ,  0.61167629,  1.03099952,
#         0.93128012, -0.83921752, -0.30921238,  0.33126343,  0.97554513,
#        -0.47917424, -0.18565898, -1.10633497, -1.19620662,  0.81252582,
# ...

# %%
dates = pd.date_range(start = '2025/01/01', end = '2025/07/19',freq = 'D')

# %%
len(dates)
# Out:
# 200

# %%
dates
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04',
#                '2025-01-05', '2025-01-06', '2025-01-07', '2025-01-08',
#                '2025-01-09', '2025-01-10',
#                ...
#                '2025-07-10', '2025-07-11', '2025-07-12', '2025-07-13',
#                '2025-07-14', '2025-07-15', '2025-07-16', '2025-07-17',
#                '2025-07-18', '2025-07-19'],
#               dtype='datetime64[ns]', length=200, freq='D')

# %%
df = pd.DataFrame(values, index = dates, columns = ['value'])

# %%
df
# Out:
#                value
# 2025-01-01  0.496714
# 2025-01-02 -0.138264
# 2025-01-03  0.647689
# 2025-01-04  1.523030
# 2025-01-05 -0.234153
# ...              ...
# 2025-07-15  0.385317
# 2025-07-16 -0.883857
# 2025-07-17  0.153725
# 2025-07-18  0.058209
# 2025-07-19 -1.142970
#
# [200 rows x 1 columns]

# %%
df['value'].plot(kind = 'hist', bins = 20, title = 'Values')
# Out:
# <Axes: title={'center': 'Values'}, ylabel='Frequency'>

# %%
df['value'].plot(kind = 'line', figsize = (8,4), title = 'Values')
# Out:
# <Axes: title={'center': 'Values'}>

# %%
plt.figure(figsize = (8,4))
plt.plot(df['value'])
plt.xlabel('Date')
plt.ylabel('Freq')
plt.title('Synthetic Time Series Dataset')
plt.show()

# %%
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day
df['weekday'] = df.index.weekday
df
# Out:
#                value  year  month  day  weekday
# 2025-01-01  0.496714  2025      1    1        2
# 2025-01-02 -0.138264  2025      1    2        3
# 2025-01-03  0.647689  2025      1    3        4
# 2025-01-04  1.523030  2025      1    4        5
# 2025-01-05 -0.234153  2025      1    5        6
# ...              ...   ...    ...  ...      ...
# 2025-07-15  0.385317  2025      7   15        1
# 2025-07-16 -0.883857  2025      7   16        2
# 2025-07-17  0.153725  2025      7   17        3
# 2025-07-18  0.058209  2025      7   18        4
# 2025-07-19 -1.142970  2025      7   19        5
#
# [200 rows x 5 columns]

# %%
df['lag_01']  = df['value'].shift(1)

# %%
df
# Out:
#                value  year  month  day  weekday    lag_01
# 2025-01-01  0.496714  2025      1    1        2       NaN
# 2025-01-02 -0.138264  2025      1    2        3  0.496714
# 2025-01-03  0.647689  2025      1    3        4 -0.138264
# 2025-01-04  1.523030  2025      1    4        5  0.647689
# 2025-01-05 -0.234153  2025      1    5        6  1.523030
# ...              ...   ...    ...  ...      ...       ...
# 2025-07-15  0.385317  2025      7   15        1  0.173181
# 2025-07-16 -0.883857  2025      7   16        2  0.385317
# 2025-07-17  0.153725  2025      7   17        3 -0.883857
# 2025-07-18  0.058209  2025      7   18        4  0.153725
# 2025-07-19 -1.142970  2025      7   19        5  0.058209
#
# [200 rows x 6 columns]

# %%
df['lag_02']  = df['value'].shift(2)
df
# Out:
#                value  year  month  day  weekday    lag_01    lag_02
# 2025-01-01  0.496714  2025      1    1        2       NaN       NaN
# 2025-01-02 -0.138264  2025      1    2        3  0.496714       NaN
# 2025-01-03  0.647689  2025      1    3        4 -0.138264  0.496714
# 2025-01-04  1.523030  2025      1    4        5  0.647689 -0.138264
# 2025-01-05 -0.234153  2025      1    5        6  1.523030  0.647689
# ...              ...   ...    ...  ...      ...       ...       ...
# 2025-07-15  0.385317  2025      7   15        1  0.173181 -1.245739
# 2025-07-16 -0.883857  2025      7   16        2  0.385317  0.173181
# 2025-07-17  0.153725  2025      7   17        3 -0.883857  0.385317
# 2025-07-18  0.058209  2025      7   18        4  0.153725 -0.883857
# 2025-07-19 -1.142970  2025      7   19        5  0.058209  0.153725
#
# [200 rows x 7 columns]

# %%
df['rolling_mean_5'] = df['value'].rolling(5).mean()
df['rolling_std_5'] = df['value'].rolling(5).std()
df['rolling_min_5'] = df['value'].rolling(5).min()
df['rolling_max_5'] = df['value'].rolling(5).max()
df
# Out:
#                value  year  month  day  weekday    lag_01    lag_02  \
# 2025-01-01  0.496714  2025      1    1        2       NaN       NaN
# 2025-01-02 -0.138264  2025      1    2        3  0.496714       NaN
# 2025-01-03  0.647689  2025      1    3        4 -0.138264  0.496714
# 2025-01-04  1.523030  2025      1    4        5  0.647689 -0.138264
# 2025-01-05 -0.234153  2025      1    5        6  1.523030  0.647689
# ...              ...   ...    ...  ...      ...       ...       ...
# 2025-07-15  0.385317  2025      7   15        1  0.173181 -1.245739
# 2025-07-16 -0.883857  2025      7   16        2  0.385317  0.173181
# 2025-07-17  0.153725  2025      7   17        3 -0.883857  0.385317
# 2025-07-18  0.058209  2025      7   18        4  0.153725 -0.883857
# 2025-07-19 -1.142970  2025      7   19        5  0.058209  0.153725
#
#             rolling_mean_5  rolling_std_5  rolling_min_5  rolling_max_5
# 2025-01-01             NaN            NaN            NaN            NaN
# ...

# %%
df['expanding_mean'] = df['value'].expanding().mean()
df['expanding_std'] = df['value'].expanding().std()
df['expanding_min'] = df['value'].expanding().min()
df['expanding_max'] = df['value'].expanding().max()
df
# Out:
#                value  year  month  day  weekday    lag_01    lag_02  \
# 2025-01-01  0.496714  2025      1    1        2       NaN       NaN
# 2025-01-02 -0.138264  2025      1    2        3  0.496714       NaN
# 2025-01-03  0.647689  2025      1    3        4 -0.138264  0.496714
# 2025-01-04  1.523030  2025      1    4        5  0.647689 -0.138264
# 2025-01-05 -0.234153  2025      1    5        6  1.523030  0.647689
# ...              ...   ...    ...  ...      ...       ...       ...
# 2025-07-15  0.385317  2025      7   15        1  0.173181 -1.245739
# 2025-07-16 -0.883857  2025      7   16        2  0.385317  0.173181
# 2025-07-17  0.153725  2025      7   17        3 -0.883857  0.385317
# 2025-07-18  0.058209  2025      7   18        4  0.153725 -0.883857
# 2025-07-19 -1.142970  2025      7   19        5  0.058209  0.153725
#
#             rolling_mean_5  rolling_std_5  rolling_min_5  rolling_max_5  \
# 2025-01-01             NaN            NaN            NaN            NaN
# ...
