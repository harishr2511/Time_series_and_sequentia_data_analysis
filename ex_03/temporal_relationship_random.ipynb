# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
date_range = pd.date_range(start = '1/1/2024', end = '1/31/2024', freq = 'D')
len(date_range)
# Out:
# 31

# %%
date_range
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10', '2024-01-11', '2024-01-12',
#                '2024-01-13', '2024-01-14', '2024-01-15', '2024-01-16',
#                '2024-01-17', '2024-01-18', '2024-01-19', '2024-01-20',
#                '2024-01-21', '2024-01-22', '2024-01-23', '2024-01-24',
#                '2024-01-25', '2024-01-26', '2024-01-27', '2024-01-28',
#                '2024-01-29', '2024-01-30', '2024-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
temp_data = np.random.normal(loc = 10, scale = 5, size = len(date_range))
temp_data
# Out:
# array([ 9.8172711 , 13.41228002,  6.28988313,  0.81793682, 10.2345729 ,
#         7.36393324, 17.81495883,  7.87085226,  4.38051978, 10.85017895,
#        13.8537787 ,  6.83916086,  6.60128954, 12.01322496, 12.5540906 ,
#         6.06100203,  6.26090649, 10.8525793 , 11.85875064,  8.33372089,
#        11.42969423,  9.68195523,  6.81179539,  4.26884061,  8.71028505,
#        14.96633811, 13.17300239, 13.75223897, 10.26649972,  9.52087013,
#         6.42674465])

# %%
temp_df = pd.DataFrame({'Date' : date_range, 'Temperature' : temp_data})
temp_df
# Out:
#          Date  Temperature
# 0  2024-01-01     9.817271
# 1  2024-01-02    13.412280
# 2  2024-01-03     6.289883
# 3  2024-01-04     0.817937
# 4  2024-01-05    10.234573
# 5  2024-01-06     7.363933
# 6  2024-01-07    17.814959
# 7  2024-01-08     7.870852
# 8  2024-01-09     4.380520
# 9  2024-01-10    10.850179
# 10 2024-01-11    13.853779
# 11 2024-01-12     6.839161
# 12 2024-01-13     6.601290
# 13 2024-01-14    12.013225
# 14 2024-01-15    12.554091
# 15 2024-01-16     6.061002
# 16 2024-01-17     6.260906
# 17 2024-01-18    10.852579
# 18 2024-01-19    11.858751
# 19 2024-01-20     8.333721
# 20 2024-01-21    11.429694
# 21 2024-01-22     9.681955
# 22 2024-01-23     6.811795
# 23 2024-01-24     4.268841
# 24 2024-01-25     8.710285
# 25 2024-01-26    14.966338
# 26 2024-01-27    13.173002
# 27 2024-01-28    13.752239
# 28 2024-01-29    10.266500
# 29 2024-01-30     9.520870
# 30 2024-01-31     6.426745

# %%
temp_df['Date'] = pd.to_datetime(temp_df['Date'])

# %%
temp_df.set_index('Date', inplace = True)
temp_df.head()
# Out:
#             Temperature
# Date
# 2024-01-01     9.817271
# 2024-01-02    13.412280
# 2024-01-03     6.289883
# 2024-01-04     0.817937
# 2024-01-05    10.234573

# %%
plt.figure(figsize = (8,3))
plt.plot(temp_df.index, temp_df['Temperature'])
plt.title('Daily Temp in Jan 2024')
plt.xlabel('Date')
plt.ylabel('Temp in Celsius')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize = (8,3))
plt.scatter(temp_df.index, temp_df['Temperature'])
plt.title('Daily Temp in Jan 2024')
plt.xlabel('Date')
plt.ylabel('Temp in Celsius')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize = (8,3))
pd.plotting.autocorrelation_plot(temp_df['Temperature'])
plt.title('Autocorrelation Plot')
plt.show()

# %%
plt.figure(figsize = (8,3))
plt.hist(temp_df['Temperature'], bins = 10)
plt.title('Histogram for Daily Temp in Jan24')
plt.xlabel('Temperature in Celsius')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize = (8,3))
sns.kdeplot(temp_df['Temperature'], fill = True)
plt.title('Density plot for Daily Temp in Jan24')
plt.xlabel('Temperature')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize = (3,2))
sns.boxplot(x = temp_df['Temperature'])
plt.title('Box and Whisker plot for Daily Temp in Jan24')
plt.xlabel('Temperature')
plt.show()

# %%
plt.figure(figsize = (2,2))
sns.heatmap(temp_df, cmap = 'coolwarm')
plt.title('Heatmap for Daily Temp in Jan24')
plt.xlabel('Temperature')
plt.show()
